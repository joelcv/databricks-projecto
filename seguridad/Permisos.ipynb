# %%
# %sql
GRANT SELECT ON TABLE gold_ventas TO analyst_group;

# %%
# %sql
CREATE VIEW ventas_region AS
SELECT *
FROM gold_ventas
WHERE region = current_user();

# %%
# %sql
ALTER ROLE db_datareader ADD MEMBER user_demo;

# %%
# %sql
GRANT ALL PRIVILEGES ON CATALOG ventas_accesorios TO `analyst`;
GRANT CREATE, USE SCHEMA ON SCHEMA  ventas_accesorios.bronze to `analyst`;
GRANT CREATE, USE SCHEMA ON SCHEMA  ventas_accesorios.silver to `analyst`;
GRANT CREATE, USE SCHEMA ON SCHEMA  ventas_accesorios.golden to `analyst`;

# %%
# %sql
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` to `analyst`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` to `analyst`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` to `analyst`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` to `analyst`;
